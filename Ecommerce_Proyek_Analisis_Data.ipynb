# %% [markdown]
# # Proyek Analisis Data: [E-Commerce Public Dataset]
# - **Nama:** Nove lorenta sihotang
# - **Email:** sihotangrenta04@gmail.com
# - **ID Dicoding:** novelorenta09

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Kategori produk mana yang menghasilkan revenue tertinggi dan terendah selama tahun 2018?
#
#   SMART-nya:
#
#     - Specific: kategori produk + revenue
#     - Measurable: total revenue
#     - Action-oriented: dapat menjadi dasar untuk mengevaluasi performa kategori produk
#     - Relevant: berkaitan langsung dengan performa penjualan
#     - Time-bound: tahun 2018
# - **Pertanyaan 2:** Seller mana yang memiliki jumlah pesanan terlambat terbanyak selama tahun 2018?
#
#   SMART-nya:
#
#   - Specific: seller + pesanan terlambat
#   - Measurable: jumlah pesanan terlambat
#   - Action-oriented: dapat digunakan untuk mengidentifikasi seller yang perlu dievaluasi dari sisi pemenuhan pesanan
#   - Relevant: berkaitan dengan operasional e-commerce dan kualitas fulfillment
#   - Time-bound: tahun 2018
# - **Pertanyaan 3:** Kota mana yang memiliki jumlah order dan customer terbanyak selama tahun 2018?
#
#   SMART-nya:
#
#   - Specific: fokus pada kota, order, dan customer.
#   - Measurable: jumlah order dan jumlah customer.
#   - Action-oriented: dapat membantu mengidentifikasi wilayah dengan aktivitas - customer dan transaksi tertinggi.
#   - Relevant: relevan untuk memahami distribusi pasar berdasarkan lokasi.
#   - Time-bound: tahun 2018

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df ...

# %%
# membaca dataset dari folder -> E-Commerece Public Dataset
customers_df = pd.read_csv('/content/E-Commerce Public Dataset/customers_dataset.csv')

order_item_df = pd.read_csv('/content/E-Commerce Public Dataset/order_items_dataset.csv')


orders_df = pd.read_csv('/content/E-Commerce Public Dataset/orders_dataset.csv')
products_df = pd.read_csv('/content/E-Commerce Public Dataset/products_dataset.csv')
sellers_df = pd.read_csv('/content/E-Commerce Public Dataset/sellers_dataset.csv')
customers_df.head()
# order_item_df.head()
# orders_df.head()
# products_df.head()
# sellers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# **Insight Gathering data:** (Opsional)
# - Terdapat 5 tabel yang akan digunakan untuk analisa proyek
# - Dalam table customers_df memiliki atribut:
#     - **customer_id** -> ID unik  untuk 1 kali transaksi/order.
#     - **customer_unique_id** -> ID asli milik pelanggan, artinya jika seorang pelanggan belanja 3 kali, ia akan punya 1 customer_unique_id, tetapi memiliki 3 customer_id yang berbeda.
# - sellers_df -> seller_id
# - orders_df -> order_id (PK) & customer_id (FK)
# - products_df -> product_id
# - order_item_df -> order_item_id (PK), order_id (FK),product_id (FK) & seller_id (FK)

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Identifying ... problem

# %%
# menilai data customer
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
# mencek data duplikasi pada table customers
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
customers_df.describe()
# Out:
# Jumlah duplikasi:  0
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
# menilai data order_item_df
order_item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
# mengubah tipe data shiping limit date
order_item_df['shipping_limit_date'] = pd.to_datetime(order_item_df['shipping_limit_date'])

# %%
# mencek data duplikasi pada table order_item
print("Jumlah duplikasi: ", order_item_df.duplicated().sum())
order_item_df.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id            shipping_limit_date          price  \
# count  112650.000000                         112650  112650.000000
# mean        1.197834  2018-01-07 15:36:52.192685312     120.653739
# min         1.000000            2016-09-19 00:15:34       0.850000
# 25%         1.000000     2017-09-20 20:57:27.500000      39.900000
# 50%         1.000000            2018-01-26 13:59:35      74.990000
# 75%         1.000000  2018-05-10 14:34:00.750000128     134.900000
# max        21.000000            2020-04-09 22:35:08    6735.000000
# std         0.705124                            NaN     183.633928
#
#        freight_value
# count  112650.000000
# mean       19.990320
# min         0.000000
# 25%        13.080000
# 50%        16.260000
# 75%        21.150000
# max       409.680000
# std        15.806405

# %%
# menilai data order
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
# karena terdapat beberapa tidak sesuai dengan tipe datanya
order_date = [
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date',
    'order_purchase_timestamp',
    'order_approved_at'
]

# 3. Jalankan looping konversi
for col in order_date:
    orders_df[col] = pd.to_datetime(orders_df[col])

# %%
# mengecek missing value pada orders
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
# mencek data duplikasi pada table orders
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi:  0
#             order_purchase_timestamp              order_approved_at  \
# count                          99441                          99281
# mean   2017-12-31 08:43:12.776581120  2017-12-31 18:35:24.098800128
# min              2016-09-04 21:15:19            2016-09-15 12:16:38
# 25%              2017-09-12 14:46:19            2017-09-12 23:24:16
# 50%              2018-01-18 23:04:36            2018-01-19 11:36:13
# 75%              2018-05-04 15:42:16            2018-05-04 20:35:10
# max              2018-10-17 17:30:18            2018-09-03 17:40:06
#
#         order_delivered_carrier_date  order_delivered_customer_date  \
# count                          97658                          96476
# mean   2018-01-04 21:49:48.138278656  2018-01-14 12:09:19.035542272
# min              2016-10-08 10:34:01            2016-10-11 13:46:32
# 25%    2017-09-15 22:28:50.249999872  2017-09-25 22:07:22.249999872
# ...

# %%
# menilai dataset seller
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
# mencek data duplikasi pada table sellers_df
print("Jumlah duplikasi: ", sellers_df.duplicated().sum())
sellers_df.describe()
# Out:
# Jumlah duplikasi:  0
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
# menilai dataset products
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
# mengecek missing value
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
# mencek data duplikasi pada table products_df
print("Jumlah duplikasi: ", products_df.duplicated().sum())
products_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
products_df[products_df['product_weight_g'] == 0]
# Out:
#                              product_id product_category_name  \
# 9769   81781c0fed9fe1ad6e8c81fca1e1cb08       cama_mesa_banho
# 13683  8038040ee2a71048d4bdbbdc985b69ab       cama_mesa_banho
# 14997  36ba42dd187055e1fbe943b2d11430ca       cama_mesa_banho
# 32079  e673e90efa65a5409ff4196c038bb5af       cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 9769                  51.0                       529.0                 1.0
# 13683                 48.0                       528.0                 1.0
# 14997                 53.0                       528.0                 1.0
# 32079                 53.0                       528.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 9769                0.0               30.0               25.0
# 13683               0.0               30.0               25.0
# 14997               0.0               30.0               25.0
# ...

# %% [markdown]
# **Steps to Take:**
# 1. DEFINE BUSINESS QUESTIONS
#
#
# 2. DATA WRANGLING
#
#     - Gathering Data
#     -  Assesing Data
#           - Menilai dataset yg telah di load
#     - Cleaning Data
#
# 3. EDA
#
# 4. ENA
#
# 5. INSIGHTS/CONCLUSION
#
# 6. RECOMMENDATION

# %% [markdown]
# **Insight Assing data:** (Opsional)
# - **Terdapat kesalahan tipe data**
#     - shipping_limit_date pada table order_item_df
# - **Terdapat missing value pada table orders_df**
#     - order_approved_at	160
#     - order_delivered_carrier_date	1783
#     - order_delivered_customer_date	2965
# - **Terdapat Inacurrate data pada table products_df**
#     - product_weight_g = 0
#
# - **Terdapat missing value pada table products_df**
#     - product_category_name	610
#     - product_name_lenght	610
#     - product_description_lenght	610
#     - product_photos_qty	610
#     - product_weight_g	2
#     - product_length_cm	2
#     - product_height_cm	2
#     - product_width_cm	2

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing ... problem

# %%
# Menangani missing value pada products_df pd product_category_name, product_name_lenght, product_description_lenght dst
# products_df.isna().sum()
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
products_df.product_category_name.value_counts()
# products_df.isna().sum()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
# menggunakan metode imputation untuk menangani missing value pada products
# Untuk product_category_name diisi dengan nilai string 'unknown'
# Untuk product_name_lenght, product_description_lenght, dan product_photos_qty: Isi dengan nilai 0 (menandakan tidak ada deskripsi/foto)
products_df['product_category_name'] = products_df['product_category_name'].fillna('unknown')
products_df['product_name_lenght'] = products_df['product_name_lenght'].fillna(0)
products_df['product_description_lenght'] = products_df['product_description_lenght'].fillna(0)
products_df['product_photos_qty'] = products_df['product_photos_qty'].fillna(0)

# %%
# karena product_weight_g, product_length_cm, product_height_cm, product_width_cm hanya hilang di 2 baris
# Imputasi dengan Median  (ga pengen dihapus)
cols = ['product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
products_df[cols] = products_df[cols].fillna(products_df[cols].median())

# %%
# products_df.describe()
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %%
# menangani masalah inacurrate pada tabel products_df kolom product_weight_g=0
# karena product yg weight yah = 0.0 hanya 4 (category:cama_mesa_banho) maka lebih baik dihapus saja dan lebih praktis
products_df = products_df[products_df['product_weight_g'] > 0]

# %%
# menggunakan metode pembiaran saja untuk menangani missing value pada  orders_df
# krna kalo mengisi tanggal dengan nilai imputation (seperti mean, median, atau mode) justru akan merusak akurasi waktu transaksi.
# solusinya utk analisa di case ini memfilter dataset untuk mengambil pesanan yang order_purchase_timestamp dan order_status.
# orders_df.describe()
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# **Insight Cleaning Data:** (Opsional)
# - Tipe data shipping_limit_date menjadi datetime yg sebelumnya objet yaitu utk melakukan analisis  berbasis waktu dan mengukur ketepatan waktu pengiriman (SLA) secara akurat.
#
# - Keputusan mengisi nilai "Unknown" pada kategori name dan angka 0 pada atribut teks/foto memastikan produk tanpa informasi lengkap tidak hilang saat dikelompokkan. Sementara itu, penggunaan nilai median pada dimensi serta penghapusan data berat 0 menjaga akurasi analisis dari  anomali.
#
# - Keputusan membiarkan missing values pada tanggal pengiriman dan aproved_at, karena nilai kosong tersebut mencerminkan status transaksi yang sebenarnya, seperti pesanan yang dibatalkan atau masih dalam proses pengiriman.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...
#
# 3 pertanyaan bisnis yang ingin diselesaikan dalam proyek EDA e-commerce  ini dalam periode tahun 2018:
#
# 1. Kategori produk mana yang menghasilkan revenue tertinggi dan terendah selama tahun 2018?
#
# 2. Seller mana yang memiliki jumlah pesanan terlambat terbanyak selama tahun 2018?
#
# 3. Kota mana yang memiliki jumlah order & customer terbanyak selama tahun 2018?

# %%
# eksplorasi data order
# orders_df.describe(include="all")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# utk melihat jumlah status dari order dan status deliverd yg akan difilter utk analisa
orders_df.groupby(by="order_status").order_id.count()
# Out:
# order_status
# approved           2
# canceled         625
# created            5
# delivered      96478
# invoiced         314
# processing       301
# shipped         1107
# unavailable      609
# Name: order_id, dtype: int64

# %%
# utk melihat jumlah status dari order dan status deliverd yg akan difilter utk analisa berdasarkan tahun
orders_df['year'] = orders_df['order_purchase_timestamp'].dt.year

orders_df.groupby(['order_status', 'year']).size()
# Out:
# order_status  year
# approved      2017        2
# canceled      2016       26
#               2017      265
#               2018      334
# created       2017        4
#               2018        1
# delivered     2016      267
#               2017    43428
#               2018    52783
# invoiced      2016       18
#               2017      175
#               2018      121
# processing    2016        2
#               2017      240
#               2018       59
# shipped       2016        9
#               2017      530
#               2018      568
# unavailable   2016        7
#               2017      457
#               2018      145
# dtype: int64

# %%
# eksplorasi data product
# products_df.describe(include="all")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
# utk melihat jumlah product
products_df.groupby(['product_category_name']).product_id.count()
# Out:
# product_category_name
# agro_industria_e_comercio      74
# alimentos                      82
# alimentos_bebidas             104
# artes                          55
# artes_e_artesanato             19
#                              ...
# tablets_impressao_imagem        9
# telefonia                    1134
# telefonia_fixa                116
# unknown                       610
# utilidades_domesticas        2335
# Name: product_id, Length: 74, dtype: int64

# %%
# eksplorasi data product
customers_df.describe(include="all")
# customers_df.head()
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     274fa6071e5e17fe303b9748641082c8  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
# mengelompokkan provinsi, kota serta banyaknya pelanggan dari kota tersebut
customers_df.groupby(['customer_state','customer_city']).customer_unique_id.count()
# Out:
# customer_state  customer_city
# AC              brasileia                  1
#                 cruzeiro do sul            3
#                 epitaciolandia             1
#                 manoel urbano              1
#                 porto acre                 1
#                                           ..
# TO              silvanopolis               1
#                 sitio novo do tocantins    2
#                 taguatinga                 3
#                 tocantinopolis             7
#                 xambioa                    3
# Name: customer_unique_id, Length: 4310, dtype: int64

# %%
# eksplorasi data order item
order_item_df.describe(include="all")
# order_item_df.head()
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %%
# eksplorasi data sellers
# sellers_df.describe(include="all")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
#  merge 3 tabel utk products, orders, order_item
orders_product_item_df = (
    orders_df
    .merge(order_item_df, on='order_id', how='inner')
    .merge(products_df, on='product_id', how='left')
)
orders_product_item_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# melihat produk apa yg banyak di order serta total harganya
orders_product_item_df.groupby(by="product_category_name").agg({
    "order_id": "nunique",
    "price": "sum"
}).sort_values(by="price", ascending=False)
# Out:
#                                order_id       price
# product_category_name
# beleza_saude                       8836  1258681.34
# relogios_presentes                 5624  1205005.68
# cama_mesa_banho                    9411  1036039.18
# esporte_lazer                      7720   988048.97
# informatica_acessorios             6689   911954.32
# ...                                 ...         ...
# flores                               29     1110.04
# casa_conforto_2                      24      760.27
# cds_dvds_musicais                    12      730.00
# fashion_roupa_infanto_juvenil         8      569.85
# seguros_e_servicos                    2      283.29
#
# [74 rows x 2 columns]

# %%
# menghitung revenue
# memfilter data yakni order status = delivered  dan tahun 2018
filter_date = orders_product_item_df[
    (orders_product_item_df['order_status'] == 'delivered') &
    (orders_product_item_df['order_purchase_timestamp'].dt.year.isin([2018]))
    ]
# menghitung revenue
category_name_revenue = (
    filter_date
    .groupby('product_category_name')['price']
    .sum()
    .reset_index()
    .sort_values(by='price', ascending=False)
)
# 4. Ambil kategori tertinggi dan terendah
top_category = category_name_revenue.iloc[0]
bottom_category = category_name_revenue.iloc[-1]

print("=== Kategori Revenue Tertinggi (2018) ===")
print(f"Kategori : {top_category['product_category_name']}")
print(f"Revenue  : {top_category['price']:,.2f}")

print("\n=== Kategori Revenue Terendah (2018) ===")
print(f"Kategori : {bottom_category['product_category_name']}")
print(f"Revenue  : {bottom_category['price']:,.2f}")
# Out:
# === Kategori Revenue Tertinggi (2018) ===
# Kategori : beleza_saude
# Revenue  : 755,724.50
#
# === Kategori Revenue Terendah (2018) ===
# Kategori : cds_dvds_musicais
# Revenue  : 65.00

# %%
# merge 3 tabel utk sellers, orders, order_item
sellers_order_item_df = (
    sellers_df
    .merge(order_item_df, on='seller_id', how='inner')
    .merge(orders_df, on='order_id', how='left')
)
sellers_order_item_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 1  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 2  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 3  d1b65fc7debc3361ea86b5f14c68d2e2                   13844  mogi guacu
# 4  d1b65fc7debc3361ea86b5f14c68d2e2                   13844  mogi guacu
#
#   seller_state                          order_id  order_item_id  \
# 0           SP  4a90af3e85dd563884e2afeab1091394              1
# 1           SP  6d953888a914b67350d5bc4d48f2acab              1
# 2           SP  bc8a5de6abf5b14f98a6135a7fb46731              2
# 3           SP  035201c3c82a97f8a25dd6bd5244b2d5              1
# 4           SP  0504447548229e075dea8441b37b1e2a              1
#
#                          product_id shipping_limit_date   price  \
# 0  ffb64e34a37740dafb6c88f1abd1fa61 2017-08-25 20:50:19  106.20
# ...

# %%
# utk mengetahui jumlah seller dari kota mana yg pesanan
sellers_order_item_df.groupby(by="seller_city").agg({
    "order_id": "nunique",
    "seller_id": "nunique",
    "shipping_limit_date" :"max",
    "price": "sum"
}).sort_values(by="price", ascending=False)
# Out:
#                 order_id  seller_id shipping_limit_date       price
# seller_city
# sao paulo          24588        694 2018-09-18 21:10:15  2702878.14
# ibitinga            6565         49 2018-09-04 20:25:09   624592.94
# curitiba            2722        127 2018-09-12 13:24:27   470759.82
# rio de janeiro      2193         96 2018-08-31 08:30:21   358413.59
# guarulhos           2071         50 2018-09-06 12:50:22   329494.38
# ...                  ...        ...                 ...         ...
# resende                1          1 2018-06-18 03:13:26       19.99
# floranopolis           2          1 2018-08-02 13:44:32       19.98
# jarinu                 1          1 2018-05-10 03:52:03       14.63
# macatuba               1          1 2017-06-14 23:25:17       13.00
# palotina               1          1 2018-07-04 23:30:34        9.99
#
# [611 rows x 4 columns]

# %%
# utk mengetahui seller dari kota mana yg pesanannya memiliki keterlambatan dengan informasi tambahan rata-rata pengiriman

sellers_order_item_df['ship_duration_days'] = (
    sellers_order_item_df['shipping_limit_date'] - sellers_order_item_df['order_purchase_timestamp']
).dt.total_seconds()/(24*3600)

sellers_order_item_df.groupby(by="seller_city").agg({
    "order_id": "nunique",
    "seller_id": "nunique",
    "order_delivered_carrier_date" :"max",
    "shipping_limit_date" :"max",
    "ship_duration_days": "mean",
    "price": "sum"
}).sort_values(by="price", ascending=False)
# Out:
#                 order_id  seller_id order_delivered_carrier_date  \
# seller_city
# sao paulo          24588        694          2018-09-03 12:56:00
# ibitinga            6565         49          2018-08-28 12:50:00
# curitiba            2722        127          2018-08-29 15:29:00
# rio de janeiro      2193         96          2018-08-29 13:53:00
# guarulhos           2071         50          2018-08-29 17:46:00
# ...                  ...        ...                          ...
# resende                1          1          2018-06-12 14:09:00
# floranopolis           2          1          2018-07-30 14:47:00
# jarinu                 1          1          2018-05-04 13:27:00
# macatuba               1          1          2017-06-12 15:12:40
# palotina               1          1          2018-07-02 12:42:00
#
#                shipping_limit_date  ship_duration_days       price
# seller_city
# sao paulo      2018-09-18 21:10:15            6.273253  2702878.14
# ...

# %%
# merge tbel orders dan customers
order_customers_df = pd.merge(
    left=orders_df,
    right= customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
order_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# jumlah koTA yg memiliki pelanggan serta jumlah pesanannya
order_customers_df.groupby(by="customer_city").agg({
    "customer_unique_id": "nunique",
    "order_id" :"nunique"
}).reset_index().sort_values(by="order_id", ascending=False)
# Out:
#        customer_city  customer_unique_id  order_id
# 3597       sao paulo               14984     15540
# 3155  rio de janeiro                6620      6882
# 453   belo horizonte                2672      2773
# 558         brasilia                2069      2131
# 1143        curitiba                1465      1521
# ...              ...                 ...       ...
# 31            agisse                   1         1
# 4059         vieiras                   1         1
# 469       bertopolis                   1         1
# 1          abadiania                   1         1
# 4113           xexeu                   1         1
#
# [4119 rows x 3 columns]

# %%
# terakhir penggabungan dataframe menjadi 1 table besar
# mulai dari seller_order_item sebagai tabel dasar
all_table_df = sellers_order_item_df.copy()

# gabung dengan order_customers_df
# ambil hanya kolom info pelanggan
all_table_df = all_table_df.merge(
    order_customers_df[['order_id','customer_unique_id','customer_city', 'customer_state', 'order_approved_at','customer_zip_code_prefix']].drop_duplicates(),
    on='order_id',
    how='left'
)

# gabung dengan orders_product_item_df
# ambil hanya kategori produk
all_table_df = all_table_df.merge(
    orders_product_item_df[['order_id','product_category_name','product_name_lenght', 'product_description_lenght', 'product_photos_qty','product_weight_g','product_length_cm','product_height_cm','product_width_cm','product_id']].drop_duplicates(),
    on=['order_id','product_id'],
    how='left'
)
all_table_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 1  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 2  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 3  d1b65fc7debc3361ea86b5f14c68d2e2                   13844  mogi guacu
# 4  d1b65fc7debc3361ea86b5f14c68d2e2                   13844  mogi guacu
#
#   seller_state                          order_id  order_item_id  \
# 0           SP  4a90af3e85dd563884e2afeab1091394              1
# 1           SP  6d953888a914b67350d5bc4d48f2acab              1
# 2           SP  bc8a5de6abf5b14f98a6135a7fb46731              2
# 3           SP  035201c3c82a97f8a25dd6bd5244b2d5              1
# 4           SP  0504447548229e075dea8441b37b1e2a              1
#
#                          product_id shipping_limit_date   price  \
# 0  ffb64e34a37740dafb6c88f1abd1fa61 2017-08-25 20:50:19  106.20
# ...

# %%
# menghapus salah satu kolom krna terisi 2x
all_table_df.drop(columns=['order_approved_at_y'], inplace=True)
# rename order_approved_at_x kembali ke nama aslinya
all_table_df = all_table_df.rename(columns={'order_approved_at_x': 'order_approved_at'})
all_table_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   seller_id                      112650 non-null  object
#  1   seller_zip_code_prefix         112650 non-null  int64
#  2   seller_city                    112650 non-null  object
#  3   seller_state                   112650 non-null  object
#  4   order_id                       112650 non-null  object
#  5   order_item_id                  112650 non-null  int64
#  6   product_id                     112650 non-null  object
#  7   shipping_limit_date            112650 non-null  datetime64[ns]
#  8   price                          112650 non-null  float64
#  9   freight_value                  112650 non-null  float64
#  10  customer_id                    112650 non-null  object
#  11  order_status                   112650 non-null  object
# ...

# %% [markdown]
# **Insight EDA:** (Opsional)
#
# Setelah dilakukan proses EDA ditemukan bahwa:
# - Kategori Revenue Tertinggi (2018) adalah produk beleza_saude dengan revenue  R$755,724.50. Produk ini memiliki permintaan (demand) yang sangat tinggi dan stabil. Hal ini menunjukkan bahwa segmen pasar ini merupakan core revenue driver bagi platform e-commerce.
#
# - Sedangkan kategori Revenue Terendah (2018) yakni produk cds_dvds_musicais dengan revenue  R$65.00. Produk ini mengalami pendapatan rendah akibat pergeseran perilaku konsumen ke media digital (streaming)
#
# - Kota Sao Paulo merupakan pusat penjual (seller hub) terbesar yang mendominasi pengiriman dengan total lebih dari 24,500 pesanan. Rata-rata durasi pengiriman dari penjual di Sao Paulo adalah 7 hari.
# - Sebaliknya kota Palotina mencatatkan durasi paling singkat (4 hari) dan Resende paling lambat (11 hari), temuan ini berasal dari lokasi dengan jumlah pesanan yang sangat sedikit (hanya 1 transaksi).
#
#
#
# - Kota Sao Paulo menjadi wilayah dengan aktivitas e-commerce tertinggi, mendominasi total pasar dengan 14,984 pelanggan dan 15,540 total pesanan.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1. Kategori produk mana yang menghasilkan revenue tertinggi dan terendah selama tahun 2018?

# %%
# status =delivered & tahun 2018
df_2018 = all_table_df[
    (all_table_df['order_status'] == 'delivered') &
    (all_table_df['order_purchase_timestamp'].dt.year == 2018)
    ].copy()
# hapus baris kategorinya kosong
df_2018_clean = df_2018.dropna(subset=['product_category_name'])
# agregasi total revenue per produk
category_revenue_df = (
    df_2018_clean
    .groupby('product_category_name')
    .agg(
        total_orders=('order_id', 'nunique'),
        total_items_sold=('order_item_id', 'count'),
        total_revenue=('price', 'sum')
    )
    .reset_index()
    .sort_values(by='total_revenue', ascending=False)
)
print("TOP 5 kategori produk yang revenue tertinggi 2018")
display(category_revenue_df.head(5))
print("TOP 5 kategori produk yang revenue terendah 2018")
display(category_revenue_df.tail(5))
# Out:
# TOP 5 kategori produk yang revenue tertinggi 2018
#      product_category_name  total_orders  total_items_sold  total_revenue
# 11            beleza_saude          5305              5841      755724.50
# 66      relogios_presentes          3418              3628      687855.20
# 13         cama_mesa_banho          4838              5802      531409.35
# 32           esporte_lazer          3973              4436      517166.26
# 44  informatica_acessorios          3972              4622      496269.30
# TOP 5 kategori produk yang revenue terendah 2018
#             product_category_name  total_orders  total_items_sold  \
# 36         fashion_roupa_feminina             8                16
# 35                fashion_esporte             5                 5
# 37  fashion_roupa_infanto_juvenil             3                 3
# 15                casa_conforto_2             7                10
# 17              cds_dvds_musicais             1                 1
#
#     total_revenue
# ...

# %%
# Set style chart
sns.set_theme(style="whitegrid")

# Figure dengan 2 subplot
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))

#  top 5
top_5 = category_revenue_df.head(5)
colors_top = ["#1f77b4", "#d3d3d3", "#d3d3d3", "#d3d3d3", "#d3d3d3"]
sns.barplot(
    data=top_5,
    x='total_revenue',
    y='product_category_name',
    hue='product_category_name',
    palette=colors_top,
    legend=False,
    ax=axes[0]
)
axes[0].set_title('Top 5 categories by revenue (2018)', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Total revenue BRL')
axes[0].set_ylabel('Product category')

# Label angka di ujung bar Top 5
for p in axes[0].patches:
    width = p.get_width()
    axes[0].annotate(
        f'R${width/1000:,.1f}k',
        (width, p.get_y() + p.get_height() / 2.),
        ha='left', va='center',
        xytext=(8, 0),
        textcoords='offset points',
        fontsize=10
    )

# bottom 5
bottom_5 = category_revenue_df.tail(5).sort_values(by='total_revenue', ascending=True)
colors_bottom = ["#d62728", "#d3d3d3", "#d3d3d3", "#d3d3d3", "#d3d3d3"]
sns.barplot(
    data=bottom_5,
    x='total_revenue',
    y='product_category_name',
    hue='product_category_name',
    palette=colors_bottom,
    legend=False,
    ax=axes[1]
)
axes[1].set_title('Bottom 5 categories by revenue 2018', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Total revenue BRL')
axes[1].set_ylabel('')

# Label angka di ujung bar Bottom 5
for p in axes[1].patches:
    width = p.get_width()
    axes[1].annotate(
        f'R$ {width:,.2f}',
        (width, p.get_y() + p.get_height() / 2.),
        ha='left', va='center',
        xytext=(8, 0),
        textcoords='offset points',
        fontsize=10
    )

plt.suptitle('E-Commerce Revenue Analysis by Product Category (2018)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 2. Seller mana yang memiliki jumlah pesanan terlambat terbanyak selama tahun 2018?

# %%
# no 2 seller mana yg memiliki jumlah pesanan terlambat terbanyak selama tahun 2018
df_2018 = all_table_df[
    (all_table_df['order_status'] == 'delivered') &
    (all_table_df['order_purchase_timestamp'].dt.year == 2018)].copy()
# filter order yg terlambat dikirim oleh seller
df_late_sellers = df_2018[df_2018['order_delivered_carrier_date'] > df_2018['shipping_limit_date']]
# agregasi jumlah order terlambat satu per ssatu
top_late_sellers_df = (
    df_late_sellers
    .groupby('seller_id')
    .agg(
        total_late_orders=('order_id', 'nunique'),
        total_late_items=('order_item_id', 'count')
    )
    .reset_index()
    .sort_values(by='total_late_orders', ascending=False)
)
# 10 seller paling lambat
print("TOP 10 seller dengan pesanan terlambat terbanyak 2018")
display(top_late_sellers_df.head(10))
# Out:
# TOP 10 seller dengan pesanan terlambat terbanyak 2018
#                             seller_id  total_late_orders  total_late_items
# 465  7c67e1448b00f6e969d365cea6b010ab                164               253
# 28   06a2c3af7b3aee5d69171b0e14f0ee87                121               127
# 515  88460e8ebdecbfecb5f9601833981930                111               142
# 64   1025f0e2d44d7041d6cf58b6550e0bfa                 90               127
# 467  7d13fca15225358621be4086e1eb0964                 83                84
# 122  1f50f920176fa81dab994f9023523100                 78               110
# 239  3d871de0142ce09b7081e2b9d1733cb1                 69                71
# 728  c70c1b0d8ca86052f45a432a38b73958                 61                74
# 187  2eb70248d66e0e3ef83659f71b244378                 60                62
# 865  ea8482cd71df3c1969d7b9473ff13abc                 59                62

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(12,6))
# ambil 10 top
top_10_late =top_late_sellers_df.head(10)
# potong id seller jdi 8 karakter
top_10_late['seller_short_id'] = top_10_late['seller_id'].str[:8] + '...'
colors_top = ["#d62728", "#d3d3d3", "#d3d3d3", "#d3d3d3", "#d3d3d3","#d3d3d3", "#d3d3d3", "#d3d3d3", "#d3d3d3","#d3d3d3"]
ax = sns.barplot(
    data=top_10_late,
    x='total_late_orders',
    y='seller_short_id',
    hue='seller_short_id',
    palette =colors_top,
    legend=False)
plt.title('Top 10 Sellers with Most Delayed Carrier Deliveries (2018)', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Total Delayed Orders', fontsize=12)
plt.ylabel('Seller ID', fontsize=12)

for p in ax.patches:
    width = p.get_width()
    if width > 0:
        ax.annotate(
            f'{int(width)} orders',
            (width, p.get_y() + p.get_height() / 2.),
            ha='left', va='center',
            xytext=(8, 0),
            textcoords='offset points',
            fontsize=10
        )

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2424/3316856466.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_late['seller_short_id'] = top_10_late['seller_id'].str[:8] + '...'

# %% [markdown]
# ### Pertanyaan 3. Kota mana yang memiliki jumlah order dan customer terbanyak selama tahun 2018?:

# %%
# no 3 kota mana yg memiliki jumlah order dan customer terbanyak selama tahun 2018
df_2018 = all_table_df[
    (all_table_df['order_status'] == 'delivered') &
    (all_table_df['order_purchase_timestamp'].dt.year ==2018)].copy()
# agregasi jumlah order dan custumer unik per kota
top_cities_df = (
    df_2018
    .groupby('customer_city')
    .agg(
        total_orders=('order_id','nunique'),
        total_customers=('customer_unique_id','nunique'))
    .reset_index().sort_values(by='total_orders', ascending=False))
print("top 10 kota dengan order dan customer terbanyak 2018")
display(top_cities_df.head(10))
# Out:
# top 10 kota dengan order dan customer terbanyak 2018
#               customer_city  total_orders  total_customers
# 2845              sao paulo          8891             8666
# 2492         rio de janeiro          3376             3291
# 365          belo horizonte          1527             1494
# 447                brasilia          1193             1163
# 913                curitiba           851              836
# 568                campinas           801              778
# 1214              guarulhos           673              659
# 2329           porto alegre           665              646
# 2566               salvador           649              638
# 2707  sao bernardo do campo           526              515

# %%
sns.set_theme(style="whitegrid")

# Ambil Top 10 Kota
top_10_cities = top_cities_df.head(10)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 6))
colors_city = ["#1f77b4", "#d3d3d3", "#d3d3d3", "#d3d3d3", "#d3d3d3","#d3d3d3", "#d3d3d3", "#d3d3d3", "#d3d3d3","#d3d3d3"]

sns.barplot(
    data=top_10_cities,
    x='total_orders',
    y='customer_city',
    hue='customer_city',
    palette=colors_city,
    legend=False,
    ax=axes[0]
)
axes[0].set_title('Top 10 Cities by Total Orders (2018)', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Total Orders')
axes[0].set_ylabel('City')

# Angka di ujung bar orders
for p in axes[0].patches:
    width = p.get_width()
    axes[0].annotate(
        f'{int(width):,}',
        (width, p.get_y() + p.get_height() / 2.),
        ha='left', va='center',
        xytext=(8, 0),
        textcoords='offset points',
        fontsize=10
    )

colors_cust = ["#1f77b4", "#d3d3d3", "#d3d3d3", "#d3d3d3", "#d3d3d3","#d3d3d3", "#d3d3d3", "#d3d3d3", "#d3d3d3","#d3d3d3"]

sns.barplot(
    data=top_10_cities,
    x='total_customers',
    y='customer_city',
    hue='customer_city',
    palette=colors_cust,
    legend=False,
    ax=axes[1]
)
axes[1].set_title('Top 10 Cities by Unique Customers (2018)', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Total Unique Customers')
axes[1].set_ylabel('')

# Angka di ujung bar customers
for p in axes[1].patches:
    width = p.get_width()
    axes[1].annotate(
        f'{int(width):,}',
        (width, p.get_y() + p.get_height() / 2.),
        ha='left', va='center',
        xytext=(8, 0),
        textcoords='offset points',
        fontsize=10
    )

plt.suptitle('E-Commerce City Volume Analysis (2018)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight ENA:** (Opsional)
#
# 1. Kategori Produk Revenue Tertinggi & Terendah (2018)
#     - Tertinggi: Kategori seperti beleza_suade, relogios_presenters, atau cama_mesa_banho mendominasi revenue. Ini menunjukkan demand (permintaan) pasar yang sangat kuat dan nilai transaksi yang tinggi di kategori ini selama 2018.
#
#     - Terendah: Kategori seperti cds_dvds_musicas, casa_conforto_2  menghasilkan revenue sangat kecil. Ini bisa jadi karena pasar yang niche, kurangnya promosi, atau harga produk yang terlalu mahal/murah.
#
# 2.  Seller dengan Pesanan Terlambat Terbanyak (2018)
#
#     - Terdapat 3 Seller  yang memiliki ratusan pesanan terlambat (order_delivered_carrier_date > shipping_limit_date) selama tahun 2018. Hal ini berpotensi dampak buruk pada tingkat kepuasan pelanggan.
#
# 3. Kota dengan Order & Customer Terbanyak (2018)
#
#     - Kota besar seperti Sao Paulo (SP) dan Rio de janeiro (RJ) mendominasi baik jumlah total order maupun jumlah unique customer. Jumlah order biasanya sedikit lebih tinggi dari jumlah customer unik, yang berarti ada pelanggan di kota tersebut yang melakukan repurchase (pembelian ulang).

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# **Conlclusion:**
#
# 1. Kategori produk mana yang menghasilkan revenue tertinggi dan terendah selama tahun 2018?
#
#     - Kategori **beleza_saude** (Kecantikan & Kesehatan) merupakan pendorong utama pendapatan bisnis di tahun 2018 dengan total revenue mencapai R$ 755,724.50. Kategori ini menunjukkan angka permintaan pasar yang sangat tinggi dan konsisten.
#
#     - Sebaliknya, kategori **cds_dvds_musicais** dengan revenue terendah yaitu hanya R$ 65.00, yang menandakan adanya penurunan minat pasar secara signifikan terhadap produk media fisik.
#
# 2. Seller mana yang memiliki jumlah pesanan terlambat terbanyak selama tahun 2018?
#
#     - Kota **Sao Paulo** merupakan hub penjual terbesar yang mendominasi volume transaksi dengan lebih dari 24,500 pesanan dan mempertahankan durasi pengiriman yang stabil di angka rata-rata 7 hari.
#
#     - Sebagian besar wilayah dengan volume pesanan tinggi menunjukkan konsistensi durasi pengiriman pada rentang 6–7 hari.
#     - Namun terdapat anomali durasi pada kota-kota berskala kecil (seperti Palotina atau Resende) yang kemunkinan dipengaruhi oleh jumlah sampel transaksi yang sangat minim (sample bias).
#
# 3. Kota mana yang memiliki jumlah order & customer terbanyak selama tahun 2018?
#
#     - Dari data e-commerce ini sangat terkonsentrasi di kota Sao Paulo, yang mencatatkan jumlah pelanggan tertinggi (14,984 pelanggan) dan jumlah transaksi terbesar (15,540 pesanan).
#
#     - Tingginya rasio transaksi dibandingkan jumlah pelanggan di Sao Paulo mengindikasikan bahwa kota ini memiliki tingkat repeat order yang lebih baik dibandingkan wilayah lainnya.

# %% [markdown]
# **Rekomendasi Action Item:**
#
# -  **1. Kategori produk mana yang menghasilkan revenue tertinggi dan terendah selama tahun 2018?**
#     - Prioritaskan ketersediaan stok (stock safety) untuk Top 5 Kategori Tertinggi, terutama menjelang musim belanja seperti akhir tahun. Jangan sampai terjadi stockout (kehabisan stok) pada produk-produk cash cow ini.
#
#     - Lakukan negosiasi lebih intensif dengan supplier/seller besar di kategori Top 5 ini untuk mendapatkan harga grosir yang lebih baik, guna meningkatkan margin keuntungan.
#
#     - Untuk kategori dengan revenue terendah, perlu lakukan evaluasi apakah kategori tersebut masih layak dipertahankan di platform?
#         - Jika ya, butuh strategi promosi khusus.
#         - Jika tidak, lebih baik alokasikan sumber daya (waktu, promosi, storage) ke kategori yang lebih menguntungkan.
# - **2. Seller mana yang memiliki jumlah pesanan terlambat terbanyak selama tahun 2018?**
#     - Evaluasi atau lakukan audit performa kepada Top 10 Seller terlambat serta berikan peringatan formal teguran 1, 2, 3 (jika diperlukan).
#
#     - Hubungi seller-seller tersebut untuk menginvestigasi kenapa mereka terlambat bertujuan mendapatkan alasannya.
#
#
# - **3. Kota mana yang memiliki jumlah order & customer terbanyak selama tahun 2018?**
#     - Dari hasil analisa, Alokasikan budget iklan digital (Google Ads, Social Media Ads) lebih besar ke wilayah Top 5 Kota ini untuk memaksimalkan retensi pelanggan dan akuisisi pelanggan baru di area potensial.
#
#     - Pertimbangkan untuk membuka gudang fulfillment (penyimpanan barang) atau drop-off point baru yang lebih dekat dengan kota-kota bervolume tinggi ini. Ini akan sangat membantu mengurangi biaya kirim dan mempercepat waktu pengiriman (menjawab masalah Soal No. 2 juga).
#
#     - Buat kampanye free ongkir atau diskon khusus untuk pengiriman ke kota-kota Top 10 ini untuk menjaga loyalitas pelanggan mereka.
